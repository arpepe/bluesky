# %%
import pandas as pd

# %%
sales = pd.Series([20,12,18,10]) # ข้อมูลต้องเป็นประเภทเดียวกันทั้งหมด
sales
# Out:
# 0    20
# 1    12
# 2    18
# 3    10
# dtype: int64

# %%
sales[1]
# Out:
# 12

# %%
sales[2:]
# Out:
# 2    18
# 3    10
# dtype: int64

# %%
sales[1:3] # inclusive & exclusive
# Out:
# 1    12
# 2    18
# dtype: int64

# %%
sales * 33 # แปลงเป็นเงินไทย
# Out:
# 0    660
# 1    396
# 2    594
# 3    330
# dtype: int64

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
sales.sum()
# Out:
# 60

# %%
sales.mean()
# Out:
# 15.0

# %% [markdown]
# ###  การกำหนด index

# %%
s = pd.Series([20,12,18,10],index=[['Jan','Feb','Mar','Apr']])
s  # Label index
# Out:
# Jan    20
# Feb    12
# Mar    18
# Apr    10
# dtype: int64

# %%
s['Feb']
# Out:
# Feb    12
# dtype: int64

# %%
# %matplotlib inline

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
s.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
coffee= pd.Series(['mocha','latte','espresso'])
coffee
# Out:
# 0       mocha
# 1       latte
# 2    espresso
# dtype: object
