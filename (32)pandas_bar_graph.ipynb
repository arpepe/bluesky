# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
    # for custom number format on x and y axis
# %matplotlib inline
# %config InlineBackend.figure_format= 'retina'

# %%
print(f'pandas version:{pd.__version__}')
# Out:
# pandas version:1.1.3

# %%
pd.set_option('display.max_rows',10)

# %% [markdown]
# #  Titanic Passengers

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/seaborn/raw/titanic.csv')
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
df.set_index('name'),inplace=True
df
# Out:
#   File "<ipython-input-15-1dda8694306a>", line 1
#     df.set_index_col('name'),inplace=True
#     ^
# SyntaxError: cannot assign to function call

# %%
df[:5].plot(kind='bar',title='Titanic Passenger');

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/seaborn/raw/titanic.csv',index_col="name")
df
# Out:
#                                                     survived  pclass     sex  \
# name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df[:10].plot(kind="barh",figsize=(8,4));

# %%
df[:5]["age"].plot(kind='barh');

# %%
df[:5][[ 'age','fare']].plot(kind='barh');

# %%
df[:5][['age','fare']].plot(kind='barh',color=['gold','c']);

# %%
ax=df[:5][['age','fare']].plot(kind='barh',color=['gold','c']);
ax.axvline(40,color='.6',linestyle="--",linewidth=.5)
ax.set_xlabel('score')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df.nlargest(10,'survived')['survived'].plot(kind='barh',color='.7');
